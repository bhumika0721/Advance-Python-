# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv).

# %%
cars1=pd.read_csv("C:/pandas_data/cars1 - cars1.csv")
cars2=pd.read_csv("C:/pandas_data/cars2 - cars2.csv")

# %%
cars1=pd.read_csv("C:/pandas_data/cars1 - cars1.csv")
cars2=pd.read_csv("C:/pandas_data/cars2 - cars2.csv")

# %%
cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# ...

# %% [markdown]
#    ### Step 3. Assign each to a variable called cars1 and cars2

# %%
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
cars1.drop(columns = ["displacement", "model"], inplace = True)
cars1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cars1.drop(columns = ["displacement", "model"], inplace = True)
#       2 cars1.head()
#
# NameError: name 'cars1' is not defined

# %% [markdown]
# ### Step 4. Oops, it seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1.head()
# Out:
#     mpg  cylinders horsepower  weight  acceleration  origin  \
# 0  18.0          8        130    3504          12.0       1
# 1  15.0          8        165    3693          11.5       1
# 2  18.0          8        150    3436          11.0       1
# 3  16.0          8        150    3433          12.0       1
# 4  17.0          8        140    3449          10.5       1
#
#                          car
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
cars1=cars1.loc[:,"mpg":"car"]
cars1.head()
# Out:
#     mpg  cylinders horsepower  weight  acceleration  origin  \
# 0  18.0          8        130    3504          12.0       1
# 1  15.0          8        165    3693          11.5       1
# 2  18.0          8        150    3436          11.0       1
# 3  16.0          8        150    3433          12.0       1
# 4  17.0          8        140    3449          10.5       1
#
#                          car
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
print(cars1.shape)
print(cars2.shape)
# Out:
# (198, 7)
# (200, 9)

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars =pd.concat([cars1,cars2] ,ignore_index=True)
cars
# Out:
#       mpg  cylinders horsepower  weight  acceleration  origin  \
# 0    18.0          8        130    3504          12.0       1
# 1    15.0          8        165    3693          11.5       1
# 2    18.0          8        150    3436          11.0       1
# 3    16.0          8        150    3433          12.0       1
# 4    17.0          8        140    3449          10.5       1
# ..    ...        ...        ...     ...           ...     ...
# 393  27.0          4         86    2790          15.6       1
# 394  44.0          4         52    2130          24.6       2
# 395  32.0          4         84    2295          11.6       1
# 396  28.0          4         79    2625          18.6       1
# 397  31.0          4         82    2720          19.4       1
#
#                            car  displacement  model
# 0    chevrolet chevelle malibu           NaN    NaN
# 1            buick skylark 320           NaN    NaN
# 2           plymouth satellite           NaN    NaN
# ...

# %% [markdown]
# ### Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
nr_owners = np.random.randint(15000, high=73001  ,size=398, dtype= 'l')
nr_owners
# Out:
# array([32811, 57811, 51113, 69673, 23121, 16028, 32993, 41830, 30881,
#        47543, 60627, 41950, 22177, 61659, 38249, 65919, 43887, 41907,
#        40662, 65440, 27153, 16774, 33870, 19927, 67982, 15742, 35678,
#        58241, 69296, 67600, 46337, 38430, 30159, 52372, 15766, 55204,
#        66988, 19836, 49804, 47143, 43178, 54262, 17741, 33806, 15376,
#        39643, 20744, 15765, 31539, 40192, 68795, 16535, 23324, 55538,
#        44139, 56111, 24844, 36478, 41614, 21352, 28126, 67507, 23102,
#        71608, 58014, 16606, 46948, 47490, 48945, 18632, 55720, 35376,
#        31957, 44969, 57518, 53558, 32160, 50352, 72130, 52943, 66374,
#        70226, 24403, 56430, 49791, 24552, 49759, 60964, 41454, 64959,
#        35893, 53587, 41933, 42718, 29634, 67957, 29411, 52219, 46443,
#        36570, 41526, 44071, 61608, 49876, 27979, 44905, 47053, 62643,
#        38970, 59693, 57539, 54296, 27347, 31555, 57105, 28006, 23128,
# ...

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars["owners"]=nr_owners
cars.head()
# Out:
#     mpg  cylinders horsepower  weight  acceleration  origin  \
# 0  18.0          8        130    3504          12.0       1
# 1  15.0          8        165    3693          11.5       1
# 2  18.0          8        150    3436          11.0       1
# 3  16.0          8        150    3433          12.0       1
# 4  17.0          8        140    3449          10.5       1
#
#                          car  displacement  model  owners
# 0  chevrolet chevelle malibu           NaN    NaN   32811
# 1          buick skylark 320           NaN    NaN   57811
# 2         plymouth satellite           NaN    NaN   51113
# 3              amc rebel sst           NaN    NaN   69673
# 4                ford torino           NaN    NaN   23121

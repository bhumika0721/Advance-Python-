# %% [markdown]
# # Import library

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # load dataset

# %%
pd.read_csv("Sales Data.csv")
# Out:
#         Unnamed: 0  Order ID                 Product  Quantity Ordered  \
# 0                0    295665      Macbook Pro Laptop                 1
# 1                1    295666      LG Washing Machine                 1
# 2                2    295667    USB-C Charging Cable                 1
# 3                3    295668        27in FHD Monitor                 1
# 4                4    295669    USB-C Charging Cable                 1
# ...            ...       ...                     ...               ...
# 185945       13617    222905  AAA Batteries (4-pack)                 1
# 185946       13618    222906        27in FHD Monitor                 1
# 185947       13619    222907    USB-C Charging Cable                 1
# 185948       13620    222908    USB-C Charging Cable                 1
# 185949       13621    222909  AAA Batteries (4-pack)                 1
#
#         Price Each           Order Date  \
# 0          1700.00  2019-12-30 00:01:00
# ...

# %% [markdown]
# # Assign it to a variable called (a)

# %%
a =pd.read_csv("Sales Data.csv")

# %%
a
# Out:
#         Unnamed: 0  Order ID                 Product  Quantity Ordered  \
# 0                0    295665      Macbook Pro Laptop                 1
# 1                1    295666      LG Washing Machine                 1
# 2                2    295667    USB-C Charging Cable                 1
# 3                3    295668        27in FHD Monitor                 1
# 4                4    295669    USB-C Charging Cable                 1
# ...            ...       ...                     ...               ...
# 185945       13617    222905  AAA Batteries (4-pack)                 1
# 185946       13618    222906        27in FHD Monitor                 1
# 185947       13619    222907    USB-C Charging Cable                 1
# 185948       13620    222908    USB-C Charging Cable                 1
# 185949       13621    222909  AAA Batteries (4-pack)                 1
#
#         Price Each           Order Date  \
# 0          1700.00  2019-12-30 00:01:00
# ...

# %% [markdown]
# # Drop the unnamed:0 coulmn

# %%
a.drop( "Unnamed: 0" , axis=1 ,inplace=True)

# %%
a
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0         295665      Macbook Pro Laptop                 1     1700.00
# 1         295666      LG Washing Machine                 1      600.00
# 2         295667    USB-C Charging Cable                 1       11.95
# 3         295668        27in FHD Monitor                 1      149.99
# 4         295669    USB-C Charging Cable                 1       11.95
# ...          ...                     ...               ...         ...
# 185945    222905  AAA Batteries (4-pack)                 1        2.99
# 185946    222906        27in FHD Monitor                 1      149.99
# 185947    222907    USB-C Charging Cable                 1       11.95
# 185948    222908    USB-C Charging Cable                 1       11.95
# 185949    222909  AAA Batteries (4-pack)                 1        2.99
#
#                  Order Date                        Purchase Address  Month  \
# ...

# %% [markdown]
# # What is the number of  observation in the dataset ?

# %%
a.shape
# Out:
# (185950, 10)

# %% [markdown]
# # Print the name of all the columns ?

# %%
a.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address', 'Month', 'Sales', 'City', 'Hour'],
#       dtype='object')

# %% [markdown]
# # How is the dataset indexed ?

# %%
a.index
# Out:
# RangeIndex(start=0, stop=185950, step=1)

# %% [markdown]
# # See the first 5 entries ?

# %%
a.head(5)
# Out:
#    Order ID               Product  Quantity Ordered  Price Each  \
# 0    295665    Macbook Pro Laptop                 1     1700.00
# 1    295666    LG Washing Machine                 1      600.00
# 2    295667  USB-C Charging Cable                 1       11.95
# 3    295668      27in FHD Monitor                 1      149.99
# 4    295669  USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address  Month  \
# 0  2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12
# 1  2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12
# 2  2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12
# 3  2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12
# 4  2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12
#
#      Sales            City  Hour
# 0  1700.00   New York City     0
# 1   600.00   New York City     7
# 2    11.95   New York City    18
# ...

# %% [markdown]
# # See the last 5 entries ?

# %%
a.tail(5)
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 185945    222905  AAA Batteries (4-pack)                 1        2.99
# 185946    222906        27in FHD Monitor                 1      149.99
# 185947    222907    USB-C Charging Cable                 1       11.95
# 185948    222908    USB-C Charging Cable                 1       11.95
# 185949    222909  AAA Batteries (4-pack)                 1        2.99
#
#                  Order Date                       Purchase Address  Month  \
# 185945  2019-06-07 19:02:00          795 Pine St, Boston, MA 02215      6
# 185946  2019-06-01 19:29:00  495 North St, New York City, NY 10001      6
# 185947  2019-06-22 18:57:00  319 Ridge St, San Francisco, CA 94016      6
# 185948  2019-06-26 18:35:00   916 Main St, San Francisco, CA 94016      6
# 185949  2019-06-25 14:33:00         209 11th St, Atlanta, GA 30301      6
#
#          Sales            City  Hour
# 185945    2.99          Boston    19
# ...

# %% [markdown]
# #

# %% [markdown]
# #

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  int64
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int64
#  7   Sales             185950 non-null  float64
#  8   City              185950 non-null  object
#  9   Hour              185950 non-null  int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 14.2+ MB

# %% [markdown]
# # What is the datatype of each column ?

# %%
a.dtypes
# Out:
# Order ID              int64
# Product              object
# Quantity Ordered      int64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# Month                 int64
# Sales               float64
# City                 object
# Hour                  int64
# dtype: object

# %% [markdown]
# # Summerise the dataframe ?

# %%
a.describe()
# Out:
#             Order ID  Quantity Ordered     Price Each          Month  \
# count  185950.000000     185950.000000  185950.000000  185950.000000
# mean   230417.569379          1.124383     184.399735       7.059140
# std     51512.737110          0.442793     332.731330       3.502996
# min    141234.000000          1.000000       2.990000       1.000000
# 25%    185831.250000          1.000000      11.950000       4.000000
# 50%    230367.500000          1.000000      14.950000       7.000000
# 75%    275035.750000          1.000000     150.000000      10.000000
# max    319670.000000          9.000000    1700.000000      12.000000
#
#                Sales           Hour
# count  185950.000000  185950.000000
# mean      185.490917      14.413305
# std       332.919771       5.423416
# min         2.990000       0.000000
# 25%        11.950000      11.000000
# 50%        14.950000      15.000000
# 75%       150.000000      19.000000
# max      3400.000000      23.000000

# %% [markdown]
# # what was the best month for sales ? how much was earned that month?

# %%
result = a.groupby("Month").sum()

months=range(1,13)
plt.bar(months,result["Sales"])
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %%
months=range(1,13)
plt.bar(months,result["Sales"])
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# # Which city generates the most revenue?

# %%
city_sales = a.groupby('City').sum()
sns.barplot(x=city_sales.index, y=city_sales['Sales'], palette="plasma")
plt.title('Sales by City')
plt.xlabel('City')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\sc024\AppData\Local\Temp\ipykernel_11532\3023473869.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=city_sales.index, y=city_sales['Sales'], palette="plasma")

# %% [markdown]
#  # At what hours are customers most active?

# %%
hourly_orders = a.groupby('Hour').count()

sns.lineplot(x=hourly_orders.index, y=hourly_orders['Order ID'], marker='o')
plt.title('Number of Orders by Hour')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Orders')
plt.grid(True)
plt.show()

# %% [markdown]
# # What are the most sold products by quantity?

# %%
product_quantity = a.groupby('Product').sum().sort_values('Quantity Ordered', ascending=False)

sns.barplot(x=product_quantity['Quantity Ordered'], y=product_quantity.index, palette="coolwarm")
plt.title('Top-Selling Products (By Quantity)')
plt.xlabel('Quantity Ordered')
plt.ylabel('Product')
plt.show()
# Out:
# C:\Users\sc024\AppData\Local\Temp\ipykernel_11532\437178190.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=product_quantity['Quantity Ordered'], y=product_quantity.index, palette="coolwarm")

# %% [markdown]
# # What is the relationship between product price and quantity sold?

# %%
sns.scatterplot(x='Price Each', y='Quantity Ordered', data=a)
plt.title('Price vs Quantity Ordered')
plt.xlabel('Price ($)')
plt.ylabel('Quantity Ordered')
plt.grid(True)
plt.show()

# %% [markdown]
# # Which city shows the highest variability in sales?

# %%
sns.boxplot(x='City', y='Sales', data=a, palette='viridis')
plt.title('Sales Distribution by City (Box Plot)')
plt.xlabel('City')
plt.ylabel('Sales ($)')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sc024\AppData\Local\Temp\ipykernel_21572\2500619050.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='City', y='Sales', data=a, palette='viridis')

# %% [markdown]
# # Is there a relationship between the price of a product and the quantity ordered?

# %%
sns.lmplot(x='Price Each', y='Quantity Ordered', data=a, height=6, aspect=1.5, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
plt.title('Price vs Quantity Ordered (Linear Regression)')
plt.xlabel('Price ($)')
plt.ylabel('Quantity Ordered')
plt.grid(True)
plt.show()

# %% [markdown]
# # What percentage of total sales comes from each city?

# %%
city_sales = a.groupby('City').sum()

plt.pie(city_sales['Sales'], labels=city_sales.index, colors=sns.color_palette('pastel'))
plt.title('Sales Contribution by City')
plt.show()

# %% [markdown]
# # What is the distribution of order quantity?

# %%
sns.distplot(a['Quantity Ordered'], bins=30, color='green')
plt.title('Distribution of Quantity Ordered')
plt.xlabel('Quantity')
plt.ylabel('Density')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sc024\AppData\Local\Temp\ipykernel_11532\1652881046.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a['Quantity Ordered'], bins=30, color='green')

# %% [markdown]
# # What is the distribution of sales amount?

# %%
sns.histplot(a['Sales'], bins=50, kde=True, color='purple')
plt.title('Sales Amount Distribution')
plt.xlabel('Sales ($)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
